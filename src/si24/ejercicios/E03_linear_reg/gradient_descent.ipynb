# %% [markdown]
# ## Descenso de gradiente para regresión lineal
#
# En el ejercicio anterior aprendiste regresión lineal y encontraste una solución analítica a través de algebra lineal, ahora resolveremos el mismo problema llegando a la solución de manera iterativa.
#
# En la práctica, descenso de gradiente se utiliza en problemas en los que obtener una solución analítica no es posible como regresión logística o redes neuronales.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# Nuevamente generamos los datos aleatorios con una desviación estandar conocida
# Alrededor de una funcion lineal conocida y = 1.2x + 0.7
n_samples = 300
ruido_blanco_std = 2
X = np.random.randn(n_samples, 1)
for_bias = np.ones([n_samples, 1])
X_augmented = np.concatenate([for_bias, X], axis=-1)
eps = np.random.randn(n_samples, 1) * ruido_blanco_std
ideal_w = [[5], [1.2]]
target_y = X_augmented @ ideal_w + eps

# Dividir en entrenamiento y validación
n_val_dp = n_samples//3
x_train = X_augmented[:-n_val_dp,:]
y_train = target_y[:-n_val_dp]

x_val = X_augmented[-n_val_dp:,:]
y_val = target_y[-n_val_dp:]

print(x_train.shape, x_val.shape)
# Graficar set de entrenamiento
plt.scatter(x_train[:,-1], y_train)
# Out:
# (200, 2) (100, 2)

# %% [markdown]
# ## Función de costo
# Ya que hemos cargado el dataset y sabemos como está compuesto, debemos calcular la función de costo
#
# $ MSE = J(w) = \frac{1}{2n} \sum_{i=1}^{n} (\hat{Y}_i - Y_i)^2 $

# %%
def mse_loss(y, y_pred):
    """
        Regresa el error cuadrático promedio de todas las predicciones
        y: shape=N Etiquetas
        y_pred: predicciones del modelo
    """
    # TODO: Calcula el resultado de la función de costo
    # ====== Start of solution =====
    return loss
    # ====== End of solution =====

# Iniciamos con unos parametros w arbitrarios
w = np.random.uniform(-10, 10, size=(2, 1))

# TODO: Calcula las preddiciones para el conjunto de entrenamiento x_train
y_pred = ...

# TODO: Calcula la función de costo para las predicciones(y_pred) y los valores reales (y_train)
# ====== Start of solution =====

# ====== End of solution =====

# %% [markdown]
# Podemos visualizar como se ve la función de costo con diferentes pesos.
# Si elegimos los pesos que generan el menor costo en el set habremos encontrado los parametros ideales para este problema.

# %%
# Probaremos con 100x100 combinaciones de distintos parametros
w0 = np.linspace(-10, 10, 100)
w1 = np.linspace(-10, 10, 100)
w0w0, w1w1 = np.meshgrid(w0, w1)
w0_flat = w0w0.ravel()
w1_flat = w1w1.ravel()
W = np.stack([w0_flat, w1_flat], axis=0)


# Calculamos la función de costo
# TODO: calcula el costo de las predicciones (y_pred) contra etiquetas (y_train)
# usando las 100x100 combindaciones de parametros (W)
# ====== Start of solution =====
y_pred = ...
calc_cost = ...
# ====== End of solution =====

# Graficamos los parametros w con su respectivo costo en el eje de las x
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(w0_flat, w1_flat, calc_cost)

# TODO: Escribe a qué valor corresponde cada eje
# ====== Start of solution =====
ax.set_xlabel(...)
ax.set_ylabel(...)
ax.set_zlabel(...)
# ====== End of solution =====
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 21
#      19 fig = plt.figure()
#      20 ax = fig.add_subplot(projection='3d')
# ---> 21 ax.scatter(w0_flat, w1_flat, calc_cost)
#      23 # TODO: Escribe a qué valor corresponde cada eje
#      24 # ====== Start of solution =====
#      25 ax.set_xlabel(...)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\__init__.py:1474, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1471 @functools.wraps(func)
#    1472 def inner(ax, *args, data=None, **kwargs):
#    1473     if data is None:
# -> 1474         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1476     bound = new_sig.bind(ax, *args, **kwargs)
#    1477     auto_label = (bound.arguments.get(label_namer)
#    1478                   or bound.kwargs.get(label_namer))
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:2281, in Axes3D.scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2278 if self._zmargin < 0.05 and xs.size > 0:
#    2279     self.set_zmargin(0.05)
# -> 2281 self.auto_scale_xyz(xs, ys, zs, had_data)
#    2283 return patches
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:614, in Axes3D.auto_scale_xyz(self, X, Y, Z, had_data)
#     612     self.xy_dataLim.update_from_data_y(Y, not had_data)
#     613 if Z is not None:
# --> 614     self.zz_dataLim.update_from_data_x(Z, not had_data)
#     615 # Let autoscale_view figure out how to use this data.
#     616 self.autoscale_view()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\transforms.py:909, in Bbox.update_from_data_x(self, x, ignore)
#     893 """
#     894 Update the x-bounds of the `Bbox` based on the passed in data. After
#     895 updating, the bounds will have positive *width*, and *x0* will be the
#    (...)
#     906    - When ``None``, use the last value passed to :meth:`ignore`.
#     907 """
#     908 x = np.ravel(x)
# --> 909 self.update_from_data_xy(np.column_stack([x, np.ones(x.size)]),
#     910                          ignore=ignore, updatey=False)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\transforms.py:954, in Bbox.update_from_data_xy(self, xy, ignore, updatex, updatey)
#     951 if len(xy) == 0:
#     952     return
# --> 954 path = Path(xy)
#     955 self.update_from_path(path, ignore=ignore,
#     956                       updatex=updatex, updatey=updatey)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#      99 def __init__(self, vertices, codes=None, _interpolation_steps=1,
#     100              closed=False, readonly=False):
#     101     """
#     102     Create a new path with the given vertices and codes.
#     103
#    (...)
#     127         and codes as read-only arrays.
#     128     """
# --> 129     vertices = _to_unmasked_float_array(vertices)
#     130     _api.check_shape((None, 2), vertices=vertices)
#     132     if codes is not None:
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\cbook\__init__.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'ellipsis'
# Error in callback <function _draw_all_if_interactive at 0x000002799DECE1F0> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\backend_bases.py:2082, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2080 if not self._is_idle_drawing:
#    2081     with self._idle_draw_cntx():
# -> 2082         self.draw(*args, **kwargs)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:470, in Axes3D.draw(self, renderer)
#     466 zorder_offset = max(axis.get_zorder()
#     467                     for axis in self._axis_map.values()) + 1
#     468 collection_zorder = patch_zorder = zorder_offset
# --> 470 for artist in sorted(collections_and_patches,
#     471                      key=lambda artist: artist.do_3d_projection(),
#     472                      reverse=True):
#     473     if isinstance(artist, mcoll.Collection):
#     474         artist.zorder = collection_zorder
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:471, in Axes3D.draw.<locals>.<lambda>(artist)
#     466 zorder_offset = max(axis.get_zorder()
#     467                     for axis in self._axis_map.values()) + 1
#     468 collection_zorder = patch_zorder = zorder_offset
#     470 for artist in sorted(collections_and_patches,
# --> 471                      key=lambda artist: artist.do_3d_projection(),
#     472                      reverse=True):
#     473     if isinstance(artist, mcoll.Collection):
#     474         artist.zorder = collection_zorder
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:725, in Path3DCollection.do_3d_projection(self)
#     723 def do_3d_projection(self):
#     724     xs, ys, zs = self._offsets3d
# --> 725     vxs, vys, vzs, vis = proj3d.proj_transform_clip(xs, ys, zs,
#     726                                                     self.axes.M)
#     727     # Sort the points based on z coordinates
#     728     # Performance optimization: Create a sorted index array and reorder
#     729     # points and point properties according to the index array
#     730     z_markers_idx = self._z_markers_idx = np.argsort(vzs)[::-1]
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:231, in proj_transform_clip(xs, ys, zs, M)
#     225 """
#     226 Transform the points by the projection matrix
#     227 and return the clipping result
#     228 returns txs, tys, tzs, tis
#     229 """
#     230 vec = _vec_pad_ones(xs, ys, zs)
# --> 231 return _proj_transform_vec_clip(vec, M)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:185, in _proj_transform_vec_clip(vec, M)
#     184 def _proj_transform_vec_clip(vec, M):
# --> 185     vecw = np.dot(M, vec)
#     186     w = vecw[3]
#     187     # clip here.
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'ellipsis'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\backend_bases.py:2342, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336     renderer = _get_renderer(
#    2337         self.figure,
#    2338         functools.partial(
#    2339             print_method, orientation=orientation)
#    2340     )
#    2341     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342         self.figure.draw(renderer)
#    2344 if bbox_inches:
#    2345     if bbox_inches == "tight":
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\figure.py:3175, in Figure.draw(self, renderer)
#    3172         # ValueError can occur when resizing a window.
#    3174 self.patch.draw(renderer)
# -> 3175 mimage._draw_list_compositing_images(
#    3176     renderer, self, artists, self.suppressComposite)
#    3178 for sfig in self.subfigs:
#    3179     sfig.draw(renderer)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:470, in Axes3D.draw(self, renderer)
#     466 zorder_offset = max(axis.get_zorder()
#     467                     for axis in self._axis_map.values()) + 1
#     468 collection_zorder = patch_zorder = zorder_offset
# --> 470 for artist in sorted(collections_and_patches,
#     471                      key=lambda artist: artist.do_3d_projection(),
#     472                      reverse=True):
#     473     if isinstance(artist, mcoll.Collection):
#     474         artist.zorder = collection_zorder
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:471, in Axes3D.draw.<locals>.<lambda>(artist)
#     466 zorder_offset = max(axis.get_zorder()
#     467                     for axis in self._axis_map.values()) + 1
#     468 collection_zorder = patch_zorder = zorder_offset
#     470 for artist in sorted(collections_and_patches,
# --> 471                      key=lambda artist: artist.do_3d_projection(),
#     472                      reverse=True):
#     473     if isinstance(artist, mcoll.Collection):
#     474         artist.zorder = collection_zorder
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:725, in Path3DCollection.do_3d_projection(self)
#     723 def do_3d_projection(self):
#     724     xs, ys, zs = self._offsets3d
# --> 725     vxs, vys, vzs, vis = proj3d.proj_transform_clip(xs, ys, zs,
#     726                                                     self.axes.M)
#     727     # Sort the points based on z coordinates
#     728     # Performance optimization: Create a sorted index array and reorder
#     729     # points and point properties according to the index array
#     730     z_markers_idx = self._z_markers_idx = np.argsort(vzs)[::-1]
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:231, in proj_transform_clip(xs, ys, zs, M)
#     225 """
#     226 Transform the points by the projection matrix
#     227 and return the clipping result
#     228 returns txs, tys, tzs, tis
#     229 """
#     230 vec = _vec_pad_ones(xs, ys, zs)
# --> 231 return _proj_transform_vec_clip(vec, M)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\mpl_toolkits\mplot3d\proj3d.py:185, in _proj_transform_vec_clip(vec, M)
#     184 def _proj_transform_vec_clip(vec, M):
# --> 185     vecw = np.dot(M, vec)
#     186     w = vecw[3]
#     187     # clip here.
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# TypeError: unsupported operand type(s) for *: 'float' and 'ellipsis'

# %%
# Podemos encontrar la combinación de pesos que minimizan el costo
# Y de esta manera encontrar los pesos ideales
best_idx = np.argmin(calc_cost)
search_w0 = w0_flat[best_idx]
search_w1 = w1_flat[best_idx]
search_w = [[search_w0], [search_w1]] 

plt.scatter(X, target_y)
# TODO: Grafica la línea de regresión generada por tu modelo search_w
# Encima de las muestras dadas
# ====== Start of solution =====
pred_y = ...
plt.plot(...)
# ====== End of solution =====
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 13
#       9 # TODO: Grafica la línea de regresión generada por tu modelo search_w
#      10 # Encima de las muestras dadas
#      11 # ====== Start of solution =====
#      12 pred_y = ...
# ---> 13 plt.plot(...)
#      14 # ====== End of solution =====
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\axes\_axes.py:1690, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
# -> 1690     self.add_line(line)
#    1691 if scalex:
#    1692     self._request_autoscale_view("x")
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\axes\_base.py:2304, in _AxesBase.add_line(self, line)
#    2301 if line.get_clip_path() is None:
#    2302     line.set_clip_path(self.patch)
# -> 2304 self._update_line_limits(line)
#    2305 if not line.get_label():
#    2306     line.set_label(f'_child{len(self._children)}')
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\axes\_base.py:2327, in _AxesBase._update_line_limits(self, line)
#    2323 def _update_line_limits(self, line):
#    2324     """
#    2325     Figures out the data limit of the given line, updating self.dataLim.
#    2326     """
# -> 2327     path = line.get_path()
#    2328     if path.vertices.size == 0:
#    2329         return
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\lines.py:1028, in Line2D.get_path(self)
#    1026 """Return the `~matplotlib.path.Path` associated with this line."""
#    1027 if self._invalidy or self._invalidx:
# -> 1028     self.recache()
#    1029 return self._path
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\lines.py:664, in Line2D.recache(self, always)
#     662 if always or self._invalidy:
#     663     yconv = self.convert_yunits(self._yorig)
# --> 664     y = _to_unmasked_float_array(yconv).ravel()
#     665 else:
#     666     y = self._y
#
# File c:\Users\vicen\anaconda3\envs\ml_env\lib\site-packages\matplotlib\cbook\__init__.py:1345, in _to_unmasked_float_array(x)
#    1343     return np.ma.asarray(x, float).filled(np.nan)
#    1344 else:
# -> 1345     return np.asarray(x, float)
#
# TypeError: float() argument must be a string or a number, not 'ellipsis'

# %% [markdown]
# En el código anterior evaluamos $100 \times 100$ combinaciones de pesos posibles y encontramos los mejores pesos. En este caso solo tenemos 2 parametros que queremos estimar, por lo que encontrar la solución de esta manera es factible al tener que realizar alrededor de $100^2$ evaluaciones de la función.
#
# <b>TODO: Contesta las siguientes preguntas</b>
# - ¿Cuántas evaluaciones de la función de costo tendríamos que hacer si tuviéramos 4 parametros? Si tuviéramos 4 parámetros, tendríamos que hacer $100^4$ = $10^8$ (evaluaciones de la función de costo.)
# - ¿Qué pasaría si tuviéramos 1 millon de parametros?
# Si tuviéramos 1 millón de parámetros, tendríamos que hacer $100^1000000$ evaluaciones de la función de costo, lo cual es un número astronómico y prácticamente imposible de realizar en un tiempo razonable.
#
# Las redes neuronales tienen millones de parametros para hacer predicciones, por lo que encontrar la solución de esta manera no es factible. Se han encontrado formas más eficientes de encontrar la solución por ejemplo, a través de métodos iterativos. Uno de ellos es decenso de gradiente. Siguiendo la direccion contraria del gradiente del costo con respecto a los pesos, podemos encontrar los parámetros que <b>minimizan</b> la función de costo utilizando menos evaluaciones.

# %% [markdown]
# ## Descenso de gradiente
# En esta sección, optimizarás la función de regresión lineal a través de descenso de gradiente.
# La predicción de nuestro modelo está dada con la siguiente funcion:
#
# $ \hat{Y}_i = w_0 + w_1 * x$
#
# $\hat{Y} = \mathbf{X}\mathbf{w}$
#
# <!-- El gradiente de MSE con respecto a $w_0$ se calcula de la siguiente manera
#
# $ \frac{\partial J(w)}{\partial w_0} = \frac{\partial J(w)}{\partial \hat{Y}_i} * \frac{\partial \hat{Y}_i}{\partial w_0}= \frac{1}{n} \sum_{i=1}^{n} (\hat{Y}_i - Y_i) $
#
# El gradiente de MSE con respecto a $w_1$ se calcula de la siguiente manera
#
# $ \frac{\partial J(w)}{\partial w_1} = \frac{\partial J(w)}{\partial \hat{Y}_i} * \frac{\partial \hat{Y}_i}{\partial w_1} = \frac{1}{n} \sum_{i=1}^{n} (\hat{Y}_i - Y_i) * x_i $ -->
#
# Donde:
# - $\hat{Y}_i \in  \hat{Y}$
# - $\mathbf{Y} \in \mathbb{R}^{N}$
# - $\mathbf{X} \in  \mathbb{R}^{N \times D}$ en notación aumentada
# - $\mathbf{w} \in \mathbb{R}^{D}$ en notación aumentada
#
# Como vimos en clase, el gradiente la función de costo con respecto a los pesos está dado por:
#
#  $\frac{\partial J(\mathbf{w})}{\partial \mathbf{w}} = -\frac{1}{N}X^T\epsilon$
#
#  donde $\epsilon=\mathbf{Y}-\mathbf{X}\mathbf{w}$
#
#  TODO: Completa el código necesario para aplicar descenso de gradiente durante n_iteraciones. Para ello realiza los siguientes pasos:
# - Calcula el valor de las predicciones $\mathbf{Y}$
# - Calcula el gradiente de la función a optimizar $\frac{\partial J(\mathbf{w})}{\partial \mathbf{w}}$
# - Actualiza los pesos con el gradiente $\mathbf{w}^{i+1} = \mathbf{w}^{i} - \alpha \frac{\partial J(\mathbf{w})}{\partial \mathbf{w}}$
# - Repite hasta optener el valor óptimo de $\mathbf{w}$
#
# Es tiempo de programarlo en código

# %%
def gradient_descent(X, y, lr, N_iterations, w_start=np.array([0,0])):
    """
    Entradas:
    X: arreglo con los datos en notación aumentada X
    y: vector de etiquetas
    lr: ritmo de aprendizaje
    N_iterations: cantidad de iteraciones de optimización
    w_start: pesos iniciales
        
    Regresa:  
    w_opt: pesos óptimos
    cost_history: arreglo con el valor del costo para cada iteración
    """
    m = X.shape[0]
    
    # initialize the coefficients
    w=w_start
    
    for i in range(N_iterations):
        # ====== Start of solution =====
        # TODO: Calcula la predicción 
        hypothesis = ...

        # TODO: Calcula el error


        # TODO: Calcula el gradiente del MSE loss


        # TODO: Actualiza los pesos

        
        # ====== End of solution =====
        # Calculamos la función de costo y guardamos el resultado
        loss = mse_loss(y, hypothesis)

    print(f"Total de evaluaciones {i}, el costo final fue {loss}")
    w_opt=w
    return w_opt

# %%
from sklearn import linear_model
# Parámetros de descenso de gradiente
N_iterations = [50,60,80]

# Pesos iniciales y ritmo de aprendizaje
lr = 0.1  # Utiliza valores cercanos e.g. 0.05, 0.2 .. etc
w_start = np.array([-400,0])
w_start = np.expand_dims(w_start,-1)

# (2.) - (4.) -> Variación de cantidad de iteraciones
plt.figure(figsize=(7,7))
plt.scatter(x_val[:,-1], y_val)
for n_it in N_iterations:
    # Entrenamos el modelo en el set de entrenamiento
    w_opt = gradient_descent(x_train, y_train, lr, n_it, w_start)

    # Visualizamos la predicción en el set de validación
    prediction = x_val @ w_opt
    plt.plot(x_val[:,-1], prediction, label = str(n_it)+" Iteraciones de GD", linewidth=3)

# Obtener la solución analítica
analitic_sol=linear_model.LinearRegression()
analitic_sol.fit(x_train, y_train)

# Visualizar solución analitica
plt.plot(x_val[:,-1], analitic_sol.predict(x_val),label = 'Solución analítica', linewidth=1, linestyle="dashed", color="black")
# plt.ylim(bottom=-10)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn import linear_model
#       2 # Parámetros de descenso de gradiente
#       3 N_iterations = [50,60,80]
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# <b>TODO: Contesta las siguientes preguntas</b>
# - ¿Cuántas evaluaciones de la función de costo se evaluaron para encontrar la solución con un $lr=0.1$? ¿Cómo se compara este número a la solución por busqueda exhaustiva?
# Para encontrar la solución con $lr=0.1$, el número total de evaluaciones de la función de costo fue igual a la cantidad de iteraciones definidas en el bucle de descenso de gradiente. Por lo tanto, si el número de iteraciones es $N$, entonces se realizaron $N$ evaluaciones de la función de costo. Esto es significativamente menor que el enfoque de búsqueda exhaustiva, donde tendríamos que realizar $100^2$ evaluaciones de la función de costo.
#
# - ¿Qué pasa si cambiamos la tasa de aprendizaje $(lr)$ a un valor dos veces grande?
# Si aumentamos la tasa de aprendizaje $(lr)$ a un valor dos veces más grande, es probable que el algoritmo de descenso de gradiente converja más rápidamente, ya que cada actualización de los pesos será más grande. Sin embargo, si $(lr)$ es demasiado grande, el algoritmo podría oscilar alrededor del mínimo global o incluso divergir.
#
# - ¿Qué pasa si cambiamos la tase de aprendizaje a un valor dos veces más chico?
# Si reducimos la tasa de aprendizaje $(lr)$ a un valor dos veces más pequeño, el algoritmo de descenso de gradiente podría converger más lentamente, ya que las actualizaciones de los pesos serán más pequeñas. Esto puede llevar a un mayor número de iteraciones necesarias para alcanzar la convergencia o incluso a quedar atrapado en mínimos locales.
#
#
# - ¿Qué pasa si cambiamos la tasa de aprendizaje (lr) por un valor muy grande?
# Si la tasa de aprendizaje $(lr)$ es muy grande, las actualizaciones de los pesos serán demasiado grandes y es probable que el algoritmo de descenso de gradiente diverja. Esto puede resultar en valores de pérdida que aumentan infinitamente o oscilan en torno al mínimo global, sin converger adecuadamente. En resumen, un $(lr)$ muy grande puede hacer que el algoritmo sea inestable y no converja.
